# %% [markdown]
# <a href="https://colab.research.google.com/github/taylan-sen/CIS355_FALL05/blob/main/OpenCV_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this assignment, complete all tasks and answser all questions in the Questions sections. Upload your completed ipynb.

# %% [markdown]
# https://youtu.be/FYwDAJu4hT4
#
# Watch the above video.

# %% [markdown]
# ### Questions 1
#
# 1. What is OpenCV?
# 1. Does OpenCV work in jupyter?
# 1. Name three computer vision tasks that OpenCV can do according to the video.
# 1. What does the linux wget command do?
# 1. What does the exclamation do in jupyter?
# 1. Use wget in a code cell below to download the image "https://kindnessblogdotcom1.files.wordpress.com/2015/01/taylor-swift.jpg"

# %%
# load modules including CopenCV
import numpy
import matplotlib.pyplot as plt
import cv2
print('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# The cv2.imread() function allows you to load an image into a numpy matrix/tensor (i.e. ndarray).
#
# The plt.imshow() function allows you to display an ndarray as an image in jupyter. However, plt and cv2 use different image formats - one uses BGR, one uses RGB.
#
# The numpy ndarray.copy() method creates a full copy (rather than just creating a reference).

# %%
img = cv2.imread('taylor-swift.jpg') # BGR
plt.imshow(img) # problem - RGB!
plt.show()

# %% [markdown]
# ### QUESTIONS 2
#
# 1. Create a new code cell below.
# 1. Print out the dimensions of img.
# 1. Copy img to img2 which is a deep copy, not a reference.
# 1. Swap the values of the blue and red matrices in img2.
# 1. Display the image.

# %% [markdown]
# ### QUESTIONS 3
#
# 1. Create and display new ndarray img3, which is img2 but cropped around the face.
# 1. Create and display new ndarray img4, which is identical to img3 be has 1/2 the brightness.
# 1. Create a displaynd display new ndarray img5, which has a black rectangle drawn around the eyes.

# %% [markdown]
# ### Questions 4
# 1. What is OpenCV's Canny function?
# 1. Run and display canny on the cropped img3.
